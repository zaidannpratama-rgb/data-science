# %%
import pandas as pd
transactions = pd.read_csv(r'D:\Machine_Learning\data\raw\transactions_large.csv')
customers = pd.read_csv(r'D:\Machine_Learning\data\raw\customers_large.csv')

# %%
transactions.isna().sum()
transactions = transactions.drop_duplicates()

# %%
customers.isna().sum()
customers = customers.drop_duplicates()

# %%
transactions.to_csv(r'..\data\processed\transactions_cleaned.csv', index=False)
customers.to_csv(r'..\data\processed\customers_cleaned.csv', index=False)
