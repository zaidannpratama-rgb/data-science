# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import pandas as pd
import joblib

features = pd.read_csv(r'..\data\processed\features.csv')

# %%
features['churn'] = (features['total_transactions'] < 5).astype(int)

# %%
X = features[['total_transactions']]  # Features
y = features['churn']  # Target variable

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.4)

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

print(X.shape, X_train.shape, X_test.shape)

# %%
classifier = svm.SVC(kernel='linear')
classifier.fit(X_train, y_train)

# %%
#akurasi skor dalam training data
X_train_pred = classifier.predict(X_train)
train_data_accuracy = accuracy_score( X_train_pred, y_train)

print('Accuracy score of training data : ', train_data_accuracy)

# %%
#akurasi skor dalam test data
X_test_pred = classifier.predict(X_test)
test_data_accuracy = accuracy_score(X_test_pred, y_test)

print('Accuracy score of test data : ', test_data_accuracy)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

# %%
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:", cm)

# %%
joblib.dump(scaler, r'..\models\scaler.pkl')
joblib.dump(model, r'..\models\best_model.pkl')
